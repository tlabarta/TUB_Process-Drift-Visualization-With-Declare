# %%
import pm4py
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
from pm4py.objects.conversion.log import converter as log_converter

# %%
log = pm4py.read_xes('../data/data_input/Forsage/top.xes')
df_log = log_converter.apply(log, variant=log_converter.Variants.TO_DATA_FRAME)
# Out:
# parsing log, completed traces ::   0%|          | 0/13 [00:00<?, ?it/s]

# %%
df_log
# Out:
#        Unnamed: 0  blockNumber  transactionIndex  logIndex  \
# 0           29093      9392516                 4         4
# 1           29094      9392516                 4         5
# 2           29095      9392516                 4         6
# 3           29096      9392516                 4         8
# 4           29097      9392691                16        61
# ...           ...          ...               ...       ...
# 34062     8545748     11644912               116       147
# 34063     8545749     11710917               124       142
# 34064     8545750     11710917               124       143
# 34065     8545751     11738520               121       156
# 34066     8545752     11738520               121       157
#
#                                          referrer             concept:name  \
# 0      0x81ca1e4de24136ebcf34ca518af87f18fd39d45e  New User-Place Matrix-1
# 1      0xe9a3d1ef0cb53d242136ba7aa9b18d5c8f684cd3  New User-Place Matrix-2
# 2      0x81ca1e4de24136ebcf34ca518af87f18fd39d45e  New User-Place Matrix-2
# 3                                                         Register As User
# 4                                                           Refer New User
# ...                                           ...                      ...
# 34062                                                       Refer New User
# 34063                                                    Reinvest Matrix-1
# 34064  0x7d95a6bbd5c7a7bf7f4b826dead66e55293500a3  New User-Place Matrix-1
# 34065                                                    Reinvest Matrix-1
# 34066  0x7d95a6bbd5c7a7bf7f4b826dead66e55293500a3  New User-Place Matrix-1
#
#       level  ident:eid place            time:timestamp     userId  \
# 0       1.0  eid580111   1.0 2020-01-31 22:38:31+01:00
# 1       1.0  eid580112   2.0 2020-01-31 22:38:31+01:00
# 2       1.0  eid580113   6.0 2020-01-31 22:38:31+01:00
# 3            eid580108       2020-01-31 22:38:31+01:00       64.0
# 4            eid580823       2020-01-31 23:18:04+01:00       96.0
# ...     ...        ...   ...                       ...        ...
# 34062        eid813174       2021-01-13 06:05:13+01:00  1040976.0
# 34063   3.0  eid886755       2021-01-23 09:08:46+01:00
# 34064   3.0  eid886763   3.0 2021-01-23 09:08:46+01:00
# 34065   4.0  eid911744       2021-01-27 14:59:07+01:00
# 34066   4.0  eid911749   2.0 2021-01-27 14:59:07+01:00
#
#                                          referred  \
# 0
# 1
# 2
# 3      0x81ca1e4de24136ebcf34ca518af87f18fd39d45e
# 4
# ...                                           ...
# 34062
# 34063
# 34064
# 34065
# 34066
#
#                                              user  \
# 0
# 1
# 2
# 3
# 4      0x66eb5fd3a5e2598e5cb6b46d7115bf28e479924a
# ...                                           ...
# 34062  0xa03f291f5a107807633eeb44eadf3ed4180a6752
# 34063
# 34064
# 34065
# 34066
#
#                                            caller  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...
# 34062
# 34063  0x3850136570d58b1c212603066be020422eb2f39a
# 34064
# 34065  0x3850136570d58b1c212603066be020422eb2f39a
# 34066
#
#                                   currentReferrer from  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...  ...
# 34062
# 34063  0x7d95a6bbd5c7a7bf7f4b826dead66e55293500a3
# 34064
# 34065  0x7d95a6bbd5c7a7bf7f4b826dead66e55293500a3
# 34066
#
#                                 case:concept:name  \
# 0      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# 1      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# 2      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# 3      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# 4      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# ...                                           ...
# 34062  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
# 34063  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
# 34064  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
# 34065  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
# 34066  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
#
#                                   case:ident:piid
# 0      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# 1      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# 2      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# 3      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# 4      0x4aaa7083535965d1cdd44d1407dcb11eec3f576d
# ...                                           ...
# 34062  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
# 34063  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
# 34064  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
# 34065  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
# 34066  0x132035aac2167abe5f6ad81e24fdcfeacfaed212
#
# [34067 rows x 18 columns]
